# %% [markdown]
# # Hyperparameter Optimization

# %%
import pandas as pd
import numpy as np

from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing 
from sklearn import decomposition 
from sklearn import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.shape
# Out:
# (2000, 21)

# %%
df_test.shape
# Out:
# (1000, 21)

# %%
df_train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
X = df_train.drop('price_range', axis=1).values
y = df_train.price_range.values

# %% [markdown]
# ## Random Forest Classifier

# %%
class RandomForestGridSearch:
    def __init__(self, n_jobs=-1):  #-1 uses all the cpu to its max
        self.classifier = RandomForestClassifier(n_jobs=n_jobs)
        self.param_grid = {
            'n_estimators': [100, 200, 300, 400],
            'max_depth': [1, 3, 5, 7],
            'criterion': ['gini', 'entropy']
        }
        self.model = None

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=1, cv=5):
        self.model = GridSearchCV(
            estimator=self.classifier,
            param_grid=self.param_grid,
            scoring=scoring, #all the classes have the same number of samples so we use accuracy
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage

random_forest_search = RandomForestGridSearch(n_jobs=-1)
random_forest_search.fit(X, y)
random_forest_search.print_best_results()
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.565 total time=   0.1s
# [CV 2/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.568 total time=   0.1s
# [CV 3/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.615 total time=   0.1s
# [CV 4/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.593 total time=   0.1s
# [CV 5/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.578 total time=   0.1s
# [CV 1/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.588 total time=   0.3s
# [CV 2/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.605 total time=   0.3s
# [CV 3/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.598 total time=   0.3s
# [CV 4/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.605 total time=   0.3s
# [CV 5/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.578 total time=   0.3s
# [CV 1/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.590 total time=   0.5s
# [CV 2/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.583 total time=   0.4s
# [CV 3/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.613 total time=   0.4s
# [CV 4/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.570 total time=   0.4s
# [CV 5/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.565 total time=   0.4s
# [CV 1/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.565 total time=   0.7s
# [CV 2/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.575 total time=   1.0s
# [CV 3/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.613 total time=   0.7s
# [CV 4/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.570 total time=   0.6s
# [CV 5/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.573 total time=   0.6s
# [CV 1/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 1/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.777 total time=   0.1s
# [CV 2/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 2/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.782 total time=   0.1s
# [CV 3/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 3/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.820 total time=   0.1s
# [CV 4/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 4/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 5/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 5/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.762 total time=   0.1s
# [CV 1/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 1/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.795 total time=   0.4s
# [CV 2/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 2/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.785 total time=   0.3s
# [CV 3/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 3/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.828 total time=   0.3s
# [CV 4/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 4/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.805 total time=   0.3s
# [CV 5/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 5/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.792 total time=   0.3s
# [CV 1/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 1/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.800 total time=   0.5s
# [CV 2/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 2/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.805 total time=   0.5s
# [CV 3/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 3/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.825 total time=   0.4s
# [CV 4/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 4/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.802 total time=   0.5s
# [CV 5/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 5/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.795 total time=   0.5s
# [CV 1/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 1/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.790 total time=   0.7s
# [CV 2/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 2/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.775 total time=   0.7s
# [CV 3/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 3/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.825 total time=   0.6s
# [CV 4/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 4/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.797 total time=   0.6s
# [CV 5/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 5/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.805 total time=   0.6s
# [CV 1/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 1/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.830 total time=   0.1s
# [CV 2/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 2/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.828 total time=   0.1s
# [CV 3/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 3/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.845 total time=   0.1s
# [CV 4/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 4/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.828 total time=   0.1s
# [CV 5/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 5/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.823 total time=   0.1s
# [CV 1/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.825 total time=   0.3s
# [CV 2/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.848 total time=   0.3s
# [CV 3/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.853 total time=   0.3s
# [CV 4/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.843 total time=   0.3s
# [CV 5/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.828 total time=   0.3s
# [CV 1/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.843 total time=   0.5s
# [CV 2/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.853 total time=   0.5s
# [CV 3/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.863 total time=   0.5s
# [CV 4/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.835 total time=   0.5s
# [CV 5/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 1/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.843 total time=   0.7s
# [CV 2/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.843 total time=   0.7s
# [CV 3/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.865 total time=   0.7s
# [CV 4/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.830 total time=   0.7s
# [CV 5/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.830 total time=   0.7s
# [CV 1/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 2/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.877 total time=   0.2s
# [CV 3/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 4/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.868 total time=   0.2s
# [CV 5/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.840 total time=   0.2s
# [CV 1/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.863 total time=   0.4s
# [CV 2/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.868 total time=   0.4s
# [CV 3/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.895 total time=   0.4s
# [CV 4/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.877 total time=   0.4s
# [CV 5/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.840 total time=   0.4s
# [CV 1/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.873 total time=   0.6s
# [CV 2/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.870 total time=   0.6s
# [CV 3/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.892 total time=   0.6s
# [CV 4/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.845 total time=   0.6s
# [CV 5/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.843 total time=   0.6s
# [CV 1/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.870 total time=   0.8s
# [CV 2/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.868 total time=   0.9s
# [CV 3/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.877 total time=   0.9s
# [CV 4/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.858 total time=   0.9s
# [CV 5/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.840 total time=   0.8s
# [CV 1/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.550 total time=   0.1s
# [CV 2/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.555 total time=   0.1s
# [CV 3/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.560 total time=   0.1s
# [CV 4/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.527 total time=   0.1s
# [CV 5/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.520 total time=   0.1s
# [CV 1/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.562 total time=   0.3s
# [CV 2/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.542 total time=   0.3s
# [CV 3/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.545 total time=   0.3s
# [CV 4/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.547 total time=   0.3s
# [CV 5/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.552 total time=   0.3s
# [CV 1/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.578 total time=   0.4s
# [CV 2/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.573 total time=   0.5s
# [CV 3/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.570 total time=   0.4s
# [CV 4/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.575 total time=   0.4s
# [CV 5/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.547 total time=   0.5s
# [CV 1/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.580 total time=   0.6s
# [CV 2/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.555 total time=   0.6s
# [CV 3/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.545 total time=   0.6s
# [CV 4/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.585 total time=   0.6s
# [CV 5/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.565 total time=   0.6s
# [CV 1/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 1/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.777 total time=   0.1s
# [CV 2/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 2/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.708 total time=   0.1s
# [CV 3/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 3/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 4/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 4/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.782 total time=   0.1s
# [CV 5/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 5/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.718 total time=   0.1s
# [CV 1/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 1/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.760 total time=   0.3s
# [CV 2/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 2/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.733 total time=   0.3s
# [CV 3/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 3/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.820 total time=   0.3s
# [CV 4/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 4/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.790 total time=   0.3s
# [CV 5/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 5/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.762 total time=   0.3s
# [CV 1/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 1/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.785 total time=   0.5s
# [CV 2/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 2/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.755 total time=   0.5s
# [CV 3/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 3/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.785 total time=   0.5s
# [CV 4/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 4/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.775 total time=   0.5s
# [CV 5/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 5/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.760 total time=   0.5s
# [CV 1/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 1/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.802 total time=   0.7s
# [CV 2/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 2/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.777 total time=   0.7s
# [CV 3/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 3/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.785 total time=   0.7s
# [CV 4/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 4/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.795 total time=   0.7s
# [CV 5/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 5/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.757 total time=   0.7s
# [CV 1/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.830 total time=   0.1s
# [CV 2/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.840 total time=   0.2s
# [CV 3/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 4/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.802 total time=   0.1s
# [CV 5/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.823 total time=   0.1s
# [CV 1/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.838 total time=   0.4s
# [CV 2/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.825 total time=   0.4s
# [CV 3/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.855 total time=   0.4s
# [CV 4/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.818 total time=   0.4s
# [CV 5/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.845 total time=   0.4s
# [CV 1/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.828 total time=   0.6s
# [CV 2/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   0.6s
# [CV 3/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.860 total time=   0.6s
# [CV 4/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   0.6s
# [CV 5/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.820 total time=   0.6s
# [CV 1/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.833 total time=   0.8s
# [CV 2/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.853 total time=   0.8s
# [CV 3/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.858 total time=   0.8s
# [CV 4/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.833 total time=   0.8s
# [CV 5/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 5/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.850 total time=   0.8s
# [CV 1/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 1/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.858 total time=   0.2s
# [CV 2/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 2/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.855 total time=   0.2s
# [CV 3/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 3/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.882 total time=   0.2s
# [CV 4/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 4/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.853 total time=   0.2s
# [CV 5/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.833 total time=   0.2s
# [CV 1/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.850 total time=   0.4s
# [CV 2/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.875 total time=   0.4s
# [CV 3/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.873 total time=   0.4s
# [CV 4/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.863 total time=   0.4s
# [CV 5/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.855 total time=   0.4s
# [CV 1/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.875 total time=   0.7s
# [CV 2/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.860 total time=   0.7s
# [CV 3/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.880 total time=   0.7s
# [CV 4/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.855 total time=   0.7s
# [CV 5/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.853 total time=   0.7s
# [CV 1/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.865 total time=   1.0s
# [CV 2/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.858 total time=   1.0s
# [CV 3/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.900 total time=   0.9s
# [CV 4/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.850 total time=   1.0s
# [CV 5/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.853 total time=   1.0s
# Best Score: 0.8685
# Best Parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## Random Search Parameters

# %%
class MyRandomForestRandomizedSearch:
    def __init__(self, n_jobs=-1): #-1 uses all the cpu to its max
        self.classifier = RandomForestClassifier(n_jobs=n_jobs)
        self.param_dist = {
            'n_estimators': np.arange(100, 1500, 100),
            'max_depth': np.arange(1, 20),
            'criterion': ['gini', 'entropy']
        }
        self.model = None

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=1, cv=5, n_iter=10):
        self.model = RandomizedSearchCV(
            estimator=self.classifier,
            param_distributions=self.param_dist,
            scoring=scoring,
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv,
            n_iter=n_iter #do random search 10 times
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage
random_forest_random_search = MyRandomForestRandomizedSearch(n_jobs=-1)
random_forest_random_search.fit(X, y)
random_forest_random_search.print_best_results()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=entropy, max_depth=2, n_estimators=200...........
# [CV 1/5; 1/10] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.695 total time=   0.3s
# [CV 2/5; 1/10] START criterion=entropy, max_depth=2, n_estimators=200...........
# [CV 2/5; 1/10] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.677 total time=   0.3s
# [CV 3/5; 1/10] START criterion=entropy, max_depth=2, n_estimators=200...........
# [CV 3/5; 1/10] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.713 total time=   0.3s
# [CV 4/5; 1/10] START criterion=entropy, max_depth=2, n_estimators=200...........
# [CV 4/5; 1/10] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.690 total time=   0.3s
# [CV 5/5; 1/10] START criterion=entropy, max_depth=2, n_estimators=200...........
# [CV 5/5; 1/10] END criterion=entropy, max_depth=2, n_estimators=200;, score=0.690 total time=   0.3s
# [CV 1/5; 2/10] START criterion=gini, max_depth=5, n_estimators=300..............
# [CV 1/5; 2/10] END criterion=gini, max_depth=5, n_estimators=300;, score=0.825 total time=   0.5s
# [CV 2/5; 2/10] START criterion=gini, max_depth=5, n_estimators=300..............
# [CV 2/5; 2/10] END criterion=gini, max_depth=5, n_estimators=300;, score=0.865 total time=   0.5s
# [CV 3/5; 2/10] START criterion=gini, max_depth=5, n_estimators=300..............
# [CV 3/5; 2/10] END criterion=gini, max_depth=5, n_estimators=300;, score=0.880 total time=   0.5s
# [CV 4/5; 2/10] START criterion=gini, max_depth=5, n_estimators=300..............
# [CV 4/5; 2/10] END criterion=gini, max_depth=5, n_estimators=300;, score=0.833 total time=   0.5s
# [CV 5/5; 2/10] START criterion=gini, max_depth=5, n_estimators=300..............
# [CV 5/5; 2/10] END criterion=gini, max_depth=5, n_estimators=300;, score=0.818 total time=   0.5s
# [CV 1/5; 3/10] START criterion=gini, max_depth=11, n_estimators=1100............
# [CV 1/5; 3/10] END criterion=gini, max_depth=11, n_estimators=1100;, score=0.873 total time=   2.9s
# [CV 2/5; 3/10] START criterion=gini, max_depth=11, n_estimators=1100............
# [CV 2/5; 3/10] END criterion=gini, max_depth=11, n_estimators=1100;, score=0.885 total time=   2.9s
# [CV 3/5; 3/10] START criterion=gini, max_depth=11, n_estimators=1100............
# [CV 3/5; 3/10] END criterion=gini, max_depth=11, n_estimators=1100;, score=0.895 total time=   2.9s
# [CV 4/5; 3/10] START criterion=gini, max_depth=11, n_estimators=1100............
# [CV 4/5; 3/10] END criterion=gini, max_depth=11, n_estimators=1100;, score=0.873 total time=   2.9s
# [CV 5/5; 3/10] START criterion=gini, max_depth=11, n_estimators=1100............
# [CV 5/5; 3/10] END criterion=gini, max_depth=11, n_estimators=1100;, score=0.868 total time=   2.9s
# [CV 1/5; 4/10] START criterion=gini, max_depth=6, n_estimators=400..............
# [CV 1/5; 4/10] END criterion=gini, max_depth=6, n_estimators=400;, score=0.853 total time=   0.7s
# [CV 2/5; 4/10] START criterion=gini, max_depth=6, n_estimators=400..............
# [CV 2/5; 4/10] END criterion=gini, max_depth=6, n_estimators=400;, score=0.850 total time=   0.7s
# [CV 3/5; 4/10] START criterion=gini, max_depth=6, n_estimators=400..............
# [CV 3/5; 4/10] END criterion=gini, max_depth=6, n_estimators=400;, score=0.877 total time=   0.7s
# [CV 4/5; 4/10] START criterion=gini, max_depth=6, n_estimators=400..............
# [CV 4/5; 4/10] END criterion=gini, max_depth=6, n_estimators=400;, score=0.845 total time=   0.7s
# [CV 5/5; 4/10] START criterion=gini, max_depth=6, n_estimators=400..............
# [CV 5/5; 4/10] END criterion=gini, max_depth=6, n_estimators=400;, score=0.830 total time=   0.7s
# [CV 1/5; 5/10] START criterion=gini, max_depth=18, n_estimators=1300............
# [CV 1/5; 5/10] END criterion=gini, max_depth=18, n_estimators=1300;, score=0.882 total time=   3.6s
# [CV 2/5; 5/10] START criterion=gini, max_depth=18, n_estimators=1300............
# [CV 2/5; 5/10] END criterion=gini, max_depth=18, n_estimators=1300;, score=0.887 total time=   3.6s
# [CV 3/5; 5/10] START criterion=gini, max_depth=18, n_estimators=1300............
# [CV 3/5; 5/10] END criterion=gini, max_depth=18, n_estimators=1300;, score=0.897 total time=   3.6s
# [CV 4/5; 5/10] START criterion=gini, max_depth=18, n_estimators=1300............
# [CV 4/5; 5/10] END criterion=gini, max_depth=18, n_estimators=1300;, score=0.875 total time=   3.6s
# [CV 5/5; 5/10] START criterion=gini, max_depth=18, n_estimators=1300............
# [CV 5/5; 5/10] END criterion=gini, max_depth=18, n_estimators=1300;, score=0.873 total time=   3.6s
# [CV 1/5; 6/10] START criterion=entropy, max_depth=8, n_estimators=900...........
# [CV 1/5; 6/10] END criterion=entropy, max_depth=8, n_estimators=900;, score=0.877 total time=   2.3s
# [CV 2/5; 6/10] START criterion=entropy, max_depth=8, n_estimators=900...........
# [CV 2/5; 6/10] END criterion=entropy, max_depth=8, n_estimators=900;, score=0.882 total time=   2.3s
# [CV 3/5; 6/10] START criterion=entropy, max_depth=8, n_estimators=900...........
# [CV 3/5; 6/10] END criterion=entropy, max_depth=8, n_estimators=900;, score=0.900 total time=   2.2s
# [CV 4/5; 6/10] START criterion=entropy, max_depth=8, n_estimators=900...........
# [CV 4/5; 6/10] END criterion=entropy, max_depth=8, n_estimators=900;, score=0.865 total time=   2.2s
# [CV 5/5; 6/10] START criterion=entropy, max_depth=8, n_estimators=900...........
# [CV 5/5; 6/10] END criterion=entropy, max_depth=8, n_estimators=900;, score=0.860 total time=   2.2s
# [CV 1/5; 7/10] START criterion=gini, max_depth=16, n_estimators=400.............
# [CV 1/5; 7/10] END criterion=gini, max_depth=16, n_estimators=400;, score=0.882 total time=   1.1s
# [CV 2/5; 7/10] START criterion=gini, max_depth=16, n_estimators=400.............
# [CV 2/5; 7/10] END criterion=gini, max_depth=16, n_estimators=400;, score=0.892 total time=   1.0s
# [CV 3/5; 7/10] START criterion=gini, max_depth=16, n_estimators=400.............
# [CV 3/5; 7/10] END criterion=gini, max_depth=16, n_estimators=400;, score=0.897 total time=   1.0s
# [CV 4/5; 7/10] START criterion=gini, max_depth=16, n_estimators=400.............
# [CV 4/5; 7/10] END criterion=gini, max_depth=16, n_estimators=400;, score=0.885 total time=   1.1s
# [CV 5/5; 7/10] START criterion=gini, max_depth=16, n_estimators=400.............
# [CV 5/5; 7/10] END criterion=gini, max_depth=16, n_estimators=400;, score=0.870 total time=   1.0s
# [CV 1/5; 8/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 1/5; 8/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.853 total time=   2.4s
# [CV 2/5; 8/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 2/5; 8/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.863 total time=   2.4s
# [CV 3/5; 8/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 3/5; 8/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.880 total time=   2.4s
# [CV 4/5; 8/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 4/5; 8/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.843 total time=   2.4s
# [CV 5/5; 8/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 5/5; 8/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.830 total time=   2.4s
# [CV 1/5; 9/10] START criterion=gini, max_depth=1, n_estimators=900..............
# [CV 1/5; 9/10] END criterion=gini, max_depth=1, n_estimators=900;, score=0.600 total time=   1.4s
# [CV 2/5; 9/10] START criterion=gini, max_depth=1, n_estimators=900..............
# [CV 2/5; 9/10] END criterion=gini, max_depth=1, n_estimators=900;, score=0.595 total time=   1.4s
# [CV 3/5; 9/10] START criterion=gini, max_depth=1, n_estimators=900..............
# [CV 3/5; 9/10] END criterion=gini, max_depth=1, n_estimators=900;, score=0.605 total time=   1.4s
# [CV 4/5; 9/10] START criterion=gini, max_depth=1, n_estimators=900..............
# [CV 4/5; 9/10] END criterion=gini, max_depth=1, n_estimators=900;, score=0.615 total time=   1.4s
# [CV 5/5; 9/10] START criterion=gini, max_depth=1, n_estimators=900..............
# [CV 5/5; 9/10] END criterion=gini, max_depth=1, n_estimators=900;, score=0.570 total time=   1.4s
# [CV 1/5; 10/10] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 1/5; 10/10] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.880 total time=   3.5s
# [CV 2/5; 10/10] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 2/5; 10/10] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.880 total time=   3.6s
# [CV 3/5; 10/10] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 3/5; 10/10] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.895 total time=   3.5s
# [CV 4/5; 10/10] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 4/5; 10/10] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.873 total time=   3.5s
# [CV 5/5; 10/10] START criterion=gini, max_depth=14, n_estimators=1300...........
# [CV 5/5; 10/10] END criterion=gini, max_depth=14, n_estimators=1300;, score=0.873 total time=   3.5s
# Best Score: 0.8855000000000001
# Best Parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 16, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 400, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ### Grid/Random Search With Pipeline

# %%
class MyRandomForestPipeline:
    def __init__(self, n_iter=10):
        self.scaler = preprocessing.StandardScaler()
        self.pca = decomposition.PCA()
        self.rf = ensemble.RandomForestClassifier(n_jobs= -1)
        self.classifier = pipeline.Pipeline([
            ('scaling', self.scaler),
            ('pca', self.pca),
            ('rf', self.rf)
        ])
        self.param_grid = {
            'pca__n_components': np.arange(5, 10),
            'rf__n_estimators': np.arange(100, 1500, 100),
            'rf__max_depth': np.arange(1, 20),
            'rf__criterion': ['gini', 'entropy']
        }
        self.model = None
        self.n_iter = n_iter

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=-1, cv=5):
        self.model = RandomizedSearchCV(
            estimator=self.classifier,
            param_distributions=self.param_grid,
            scoring=scoring,
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv,
            n_iter=self.n_iter
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage

my_pipeline = MyRandomForestPipeline(n_iter=10)
my_pipeline.fit(X, y)
my_pipeline.print_best_results()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Score: 0.413
# Best Parameters: {'memory': None, 'steps': [('scaling', StandardScaler()), ('pca', PCA(n_components=8)), ('rf', RandomForestClassifier(criterion='entropy', max_depth=2, n_estimators=1200,
#                        n_jobs=-1))], 'verbose': False, 'scaling': StandardScaler(), 'pca': PCA(n_components=8), 'rf': RandomForestClassifier(criterion='entropy', max_depth=2, n_estimators=1200,
#                        n_jobs=-1), 'scaling__copy': True, 'scaling__with_mean': True, 'scaling__with_std': True, 'pca__copy': True, 'pca__iterated_power': 'auto', 'pca__n_components': 8, 'pca__n_oversamples': 10, 'pca__power_iteration_normalizer': 'auto', 'pca__random_state': None, 'pca__svd_solver': 'auto', 'pca__tol': 0.0, 'pca__whiten': False, 'rf__bootstrap': True, 'rf__ccp_alpha': 0.0, 'rf__class_weight': None, 'rf__criterion': 'entropy', 'rf__max_depth': 2, 'rf__max_features': 'sqrt', 'rf__max_leaf_nodes': None, 'rf__max_samples': None, 'rf__min_impurity_decrease': 0.0, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__min_weight_fraction_leaf': 0.0, 'rf__n_estimators': 1200, 'rf__n_jobs': -1, 'rf__oob_score': False, 'rf__random_state': None, 'rf__verbose': 0, 'rf__warm_start': False}

# %% [markdown]
# ### Bayesian Optimization with Gaussian Process

# %%
from functools import partial
import skopt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from functools import partial
# ----> 2 import skopt
#
# ModuleNotFoundError: No module named 'skopt'

# %%
def optimize(params, param_names, x, y):
    params = dict(zip(param_names, params))
    model = ensemble.RandomForestClassifier(**params)
    kf = model_selection.StratifiedKFold(n_splits= 5)
    accuracies = []
    for idx in kf.split( X= x, y=y):
        train_idx, test_idx = idx[0], idx[1]
        xtrain =x[train_idx]
        ytrain = y[train_idx]
        
        xtest = x[test_idx]
        ytest = y[test_idx]
        
        model.fit(xtrain, ytrain)
        preds = model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest, preds)
        accuracies.append(fold_acc)
        
    return -1.0 * np.mean(accuracies)


param_space = [
    space.Integer(3,15, name='max_depth'),
    space.Integer(100, 600, name='n_estimators'),
    space.Categorical(['gini', 'entropy'], name='criterion'),
    space.Real(0.01, 1, prior='uniform' ,name='max_features')
]
params_names = ['max_depth', 'n_estimators', 'criterion', 'max_features']

optimization_function = partial(
    optimize,
    param_names= param_names,
    x= X,
    y = y
)

result = gp_minimize(
    optimization_function,
    dimensions = param_space,
    n_calls= 15,
    n_random_starts=10,
    verbose=10,
)

print(
    dict(
        param_names,
        results.x
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 23
#      17         accuracies.append(fold_acc)
#      19     return -1.0 * np.mean(accuracies)
#      22 param_space = [
# ---> 23     space.Integer(3,15, name='max_depth'),
#      24     space.Integer(100, 600, name='n_estimators'),
#      25     space.Categorical(['gini', 'entropy'], name='criterion'),
#      26     space.Real(0.01, 1, prior='uniform' ,name='max_features')
#      27 ]
#      28 params_names = ['max_depth', 'n_estimators', 'criterion', 'max_features']
#      30 optimization_function = partial(
#      31     optimize,
#      32     param_names= param_names,
#      33     x= X,
#      34     y = y
#      35 )
#
# NameError: name 'space' is not defined
