# %% [markdown]
# # Hyperparameter Optimization

# %%
import pandas as pd
import numpy as np

from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import preprocessing 
from sklearn import decomposition 
from sklearn import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.shape
# Out:
# (2000, 21)

# %%
df_test.shape
# Out:
# (1000, 21)

# %%
df_train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
X = df_train.drop('price_range', axis=1).values
y = df_train.price_range.values

# %% [markdown]
# ## Random Forest Classifier

# %%
class RandomForestGridSearch:
    def __init__(self, n_jobs=-1):  #-1 uses all the cpu to its max
        self.classifier = RandomForestClassifier(n_jobs=n_jobs)
        self.param_grid = {
            'n_estimators': [100, 200, 300, 400],
            'max_depth': [1, 3, 5, 7],
            'criterion': ['gini', 'entropy']
        }
        self.model = None

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=1, cv=5):
        self.model = GridSearchCV(
            estimator=self.classifier,
            param_grid=self.param_grid,
            scoring=scoring, #all the classes have the same number of samples so we use accuracy
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage

random_forest_search = RandomForestGridSearch(n_jobs=-1)
random_forest_search.fit(X, y)
random_forest_search.print_best_results()
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.578 total time=   0.2s
# [CV 2/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.583 total time=   0.2s
# [CV 3/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.613 total time=   0.2s
# [CV 4/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.522 total time=   0.3s
# [CV 5/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.568 total time=   0.1s
# [CV 1/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.605 total time=   0.3s
# [CV 2/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.623 total time=   0.3s
# [CV 3/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.618 total time=   0.3s
# [CV 4/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.557 total time=   0.3s
# [CV 5/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.560 total time=   0.2s
# [CV 1/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.598 total time=   0.4s
# [CV 2/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.600 total time=   0.4s
# [CV 3/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.605 total time=   0.5s
# [CV 4/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.600 total time=   0.5s
# [CV 5/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.555 total time=   0.4s
# [CV 1/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.595 total time=   0.6s
# [CV 2/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.595 total time=   0.6s
# [CV 3/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.605 total time=   0.7s
# [CV 4/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.598 total time=   0.6s
# [CV 5/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.560 total time=   0.6s
# [CV 1/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 1/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 2/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 2/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 3/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 3/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.800 total time=   0.1s
# [CV 4/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 4/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.805 total time=   0.1s
# [CV 5/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 5/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 1/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 1/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.785 total time=   0.3s
# [CV 2/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 2/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.775 total time=   0.2s
# [CV 3/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 3/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.828 total time=   0.3s
# [CV 4/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 4/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.795 total time=   0.3s
# [CV 5/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 5/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.807 total time=   0.3s
# [CV 1/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 1/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.805 total time=   0.4s
# [CV 2/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 2/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.807 total time=   0.4s
# [CV 3/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 3/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.845 total time=   0.4s
# [CV 4/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 4/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.823 total time=   0.4s
# [CV 5/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 5/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.795 total time=   0.4s
# [CV 1/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 1/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.807 total time=   0.7s
# [CV 2/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 2/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.785 total time=   0.6s
# [CV 3/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 3/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.835 total time=   0.6s
# [CV 4/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 4/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.805 total time=   0.6s
# [CV 5/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 5/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.805 total time=   0.6s
# [CV 1/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 1/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.818 total time=   0.1s
# [CV 2/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 2/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.835 total time=   0.1s
# [CV 3/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 3/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.848 total time=   0.1s
# [CV 4/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 4/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.853 total time=   0.1s
# [CV 5/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 5/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.810 total time=   0.1s
# [CV 1/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.838 total time=   0.3s
# [CV 2/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.848 total time=   0.3s
# [CV 3/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.860 total time=   0.3s
# [CV 4/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.845 total time=   0.3s
# [CV 5/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.818 total time=   0.3s
# [CV 1/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.818 total time=   0.5s
# [CV 2/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.843 total time=   0.5s
# [CV 3/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.863 total time=   0.5s
# [CV 4/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.845 total time=   0.5s
# [CV 5/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.810 total time=   0.5s
# [CV 1/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.833 total time=   0.7s
# [CV 2/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.850 total time=   0.7s
# [CV 3/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.870 total time=   0.7s
# [CV 4/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.843 total time=   0.7s
# [CV 5/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.825 total time=   0.7s
# [CV 1/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.865 total time=   0.2s
# [CV 2/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.868 total time=   0.2s
# [CV 3/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.870 total time=   0.2s
# [CV 4/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.860 total time=   0.2s
# [CV 5/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.843 total time=   0.2s
# [CV 1/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.863 total time=   0.4s
# [CV 2/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.882 total time=   0.4s
# [CV 3/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.890 total time=   0.4s
# [CV 4/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.860 total time=   0.4s
# [CV 5/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.843 total time=   0.4s
# [CV 1/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.855 total time=   0.6s
# [CV 2/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.875 total time=   0.6s
# [CV 3/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.882 total time=   0.6s
# [CV 4/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.865 total time=   0.6s
# [CV 5/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.855 total time=   0.6s
# [CV 1/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.863 total time=   0.8s
# [CV 2/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.865 total time=   0.8s
# [CV 3/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.882 total time=   0.8s
# [CV 4/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.855 total time=   0.8s
# [CV 5/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.845 total time=   0.8s
# [CV 1/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.545 total time=   0.1s
# [CV 2/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.552 total time=   0.1s
# [CV 3/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.557 total time=   0.1s
# [CV 4/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.520 total time=   0.1s
# [CV 5/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.527 total time=   0.1s
# [CV 1/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.585 total time=   0.3s
# [CV 2/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.535 total time=   0.2s
# [CV 3/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.532 total time=   0.3s
# [CV 4/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.535 total time=   0.2s
# [CV 5/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.555 total time=   0.3s
# [CV 1/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.575 total time=   0.4s
# [CV 2/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.542 total time=   0.4s
# [CV 3/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.565 total time=   0.4s
# [CV 4/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.562 total time=   0.4s
# [CV 5/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.552 total time=   0.4s
# [CV 1/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.578 total time=   0.7s
# [CV 2/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.565 total time=   0.8s
# [CV 3/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.568 total time=   0.7s
# [CV 4/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.552 total time=   0.6s
# [CV 5/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.547 total time=   0.7s
# [CV 1/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 1/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.762 total time=   0.1s
# [CV 2/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 2/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.762 total time=   0.2s
# [CV 3/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 3/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.777 total time=   0.2s
# [CV 4/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 4/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.777 total time=   0.1s
# [CV 5/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 5/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.785 total time=   0.1s
# [CV 1/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 1/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.745 total time=   0.3s
# [CV 2/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 2/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.762 total time=   0.3s
# [CV 3/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 3/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.802 total time=   0.3s
# [CV 4/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 4/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.800 total time=   0.3s
# [CV 5/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 5/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.757 total time=   0.3s
# [CV 1/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 1/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.797 total time=   0.4s
# [CV 2/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 2/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.738 total time=   0.5s
# [CV 3/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 3/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.790 total time=   0.4s
# [CV 4/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 4/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.782 total time=   0.5s
# [CV 5/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 5/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.765 total time=   0.4s
# [CV 1/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 1/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.762 total time=   0.6s
# [CV 2/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 2/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.790 total time=   0.6s
# [CV 3/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 3/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.777 total time=   0.6s
# [CV 4/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 4/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.770 total time=   0.6s
# [CV 5/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 5/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.777 total time=   0.6s
# [CV 1/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.830 total time=   0.1s
# [CV 2/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.812 total time=   0.1s
# [CV 3/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.860 total time=   0.1s
# [CV 4/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.828 total time=   0.1s
# [CV 5/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.850 total time=   0.3s
# [CV 1/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.828 total time=   0.4s
# [CV 2/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.848 total time=   0.4s
# [CV 3/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.865 total time=   0.3s
# [CV 4/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.833 total time=   0.4s
# [CV 5/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.820 total time=   0.3s
# [CV 1/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.825 total time=   0.6s
# [CV 2/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.845 total time=   0.7s
# [CV 3/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.873 total time=   0.6s
# [CV 4/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   0.6s
# [CV 5/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.835 total time=   0.6s
# [CV 1/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.843 total time=   1.0s
# [CV 2/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.840 total time=   0.8s
# [CV 3/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.863 total time=   0.7s
# [CV 4/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.838 total time=   0.8s
# [CV 5/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 5/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.843 total time=   0.7s
# [CV 1/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 1/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.858 total time=   0.2s
# [CV 2/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 2/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.863 total time=   0.2s
# [CV 3/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 3/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.902 total time=   0.2s
# [CV 4/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 4/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.868 total time=   0.2s
# [CV 5/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.840 total time=   0.2s
# [CV 1/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.875 total time=   0.4s
# [CV 2/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.853 total time=   0.5s
# [CV 3/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.875 total time=   0.5s
# [CV 4/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.850 total time=   0.4s
# [CV 5/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.840 total time=   0.4s
# [CV 1/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.870 total time=   0.8s
# [CV 2/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.860 total time=   0.7s
# [CV 3/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.897 total time=   1.1s
# [CV 4/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.863 total time=   0.7s
# [CV 5/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.858 total time=   0.6s
# [CV 1/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.880 total time=   0.9s
# [CV 2/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.863 total time=   0.9s
# [CV 3/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.887 total time=   0.9s
# [CV 4/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.858 total time=   0.9s
# [CV 5/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.848 total time=   0.9s
# Best Score: 0.8695
# Best Parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 7, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 300, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ## Random Search Parameters

# %%
class MyRandomForestRandomizedSearch:
    def __init__(self, n_jobs=-1): #-1 uses all the cpu to its max
        self.classifier = RandomForestClassifier(n_jobs=n_jobs)
        self.param_dist = {
            'n_estimators': np.arange(100, 1500, 100),
            'max_depth': np.arange(1, 20),
            'criterion': ['gini', 'entropy']
        }
        self.model = None

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=1, cv=5, n_iter=10):
        self.model = RandomizedSearchCV(
            estimator=self.classifier,
            param_distributions=self.param_dist,
            scoring=scoring,
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv,
            n_iter=n_iter #do random search 10 times
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage
random_forest_random_search = MyRandomForestRandomizedSearch(n_jobs=-1)
random_forest_random_search.fit(X, y)
random_forest_random_search.print_best_results()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=gini, max_depth=11, n_estimators=1200............
# [CV 1/5; 1/10] END criterion=gini, max_depth=11, n_estimators=1200;, score=0.880 total time=   3.5s
# [CV 2/5; 1/10] START criterion=gini, max_depth=11, n_estimators=1200............
# [CV 2/5; 1/10] END criterion=gini, max_depth=11, n_estimators=1200;, score=0.887 total time=   3.3s
# [CV 3/5; 1/10] START criterion=gini, max_depth=11, n_estimators=1200............
# [CV 3/5; 1/10] END criterion=gini, max_depth=11, n_estimators=1200;, score=0.892 total time=   3.2s
# [CV 4/5; 1/10] START criterion=gini, max_depth=11, n_estimators=1200............
# [CV 4/5; 1/10] END criterion=gini, max_depth=11, n_estimators=1200;, score=0.868 total time=   3.1s
# [CV 5/5; 1/10] START criterion=gini, max_depth=11, n_estimators=1200............
# [CV 5/5; 1/10] END criterion=gini, max_depth=11, n_estimators=1200;, score=0.860 total time=   3.2s
# [CV 1/5; 2/10] START criterion=gini, max_depth=12, n_estimators=500.............
# [CV 1/5; 2/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.873 total time=   1.3s
# [CV 2/5; 2/10] START criterion=gini, max_depth=12, n_estimators=500.............
# [CV 2/5; 2/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.882 total time=   1.3s
# [CV 3/5; 2/10] START criterion=gini, max_depth=12, n_estimators=500.............
# [CV 3/5; 2/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.892 total time=   1.3s
# [CV 4/5; 2/10] START criterion=gini, max_depth=12, n_estimators=500.............
# [CV 4/5; 2/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.868 total time=   1.3s
# [CV 5/5; 2/10] START criterion=gini, max_depth=12, n_estimators=500.............
# [CV 5/5; 2/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.870 total time=   1.3s
# [CV 1/5; 3/10] START criterion=entropy, max_depth=3, n_estimators=900...........
# [CV 1/5; 3/10] END criterion=entropy, max_depth=3, n_estimators=900;, score=0.790 total time=   1.5s
# [CV 2/5; 3/10] START criterion=entropy, max_depth=3, n_estimators=900...........
# [CV 2/5; 3/10] END criterion=entropy, max_depth=3, n_estimators=900;, score=0.772 total time=   1.8s
# [CV 3/5; 3/10] START criterion=entropy, max_depth=3, n_estimators=900...........
# [CV 3/5; 3/10] END criterion=entropy, max_depth=3, n_estimators=900;, score=0.792 total time=   1.5s
# [CV 4/5; 3/10] START criterion=entropy, max_depth=3, n_estimators=900...........
# [CV 4/5; 3/10] END criterion=entropy, max_depth=3, n_estimators=900;, score=0.800 total time=   1.4s
# [CV 5/5; 3/10] START criterion=entropy, max_depth=3, n_estimators=900...........
# [CV 5/5; 3/10] END criterion=entropy, max_depth=3, n_estimators=900;, score=0.775 total time=   1.5s
# [CV 1/5; 4/10] START criterion=gini, max_depth=15, n_estimators=800.............
# [CV 1/5; 4/10] END criterion=gini, max_depth=15, n_estimators=800;, score=0.882 total time=   2.3s
# [CV 2/5; 4/10] START criterion=gini, max_depth=15, n_estimators=800.............
# [CV 2/5; 4/10] END criterion=gini, max_depth=15, n_estimators=800;, score=0.892 total time=   2.3s
# [CV 3/5; 4/10] START criterion=gini, max_depth=15, n_estimators=800.............
# [CV 3/5; 4/10] END criterion=gini, max_depth=15, n_estimators=800;, score=0.895 total time=   2.2s
# [CV 4/5; 4/10] START criterion=gini, max_depth=15, n_estimators=800.............
# [CV 4/5; 4/10] END criterion=gini, max_depth=15, n_estimators=800;, score=0.873 total time=   2.4s
# [CV 5/5; 4/10] START criterion=gini, max_depth=15, n_estimators=800.............
# [CV 5/5; 4/10] END criterion=gini, max_depth=15, n_estimators=800;, score=0.868 total time=   2.4s
# [CV 1/5; 5/10] START criterion=gini, max_depth=17, n_estimators=900.............
# [CV 1/5; 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.885 total time=   2.6s
# [CV 2/5; 5/10] START criterion=gini, max_depth=17, n_estimators=900.............
# [CV 2/5; 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.875 total time=   2.8s
# [CV 3/5; 5/10] START criterion=gini, max_depth=17, n_estimators=900.............
# [CV 3/5; 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.900 total time=   2.6s
# [CV 4/5; 5/10] START criterion=gini, max_depth=17, n_estimators=900.............
# [CV 4/5; 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.870 total time=   3.2s
# [CV 5/5; 5/10] START criterion=gini, max_depth=17, n_estimators=900.............
# [CV 5/5; 5/10] END criterion=gini, max_depth=17, n_estimators=900;, score=0.868 total time=   2.5s
# [CV 1/5; 6/10] START criterion=gini, max_depth=17, n_estimators=1000............
# [CV 1/5; 6/10] END criterion=gini, max_depth=17, n_estimators=1000;, score=0.885 total time=   2.8s
# [CV 2/5; 6/10] START criterion=gini, max_depth=17, n_estimators=1000............
# [CV 2/5; 6/10] END criterion=gini, max_depth=17, n_estimators=1000;, score=0.885 total time=   3.3s
# [CV 3/5; 6/10] START criterion=gini, max_depth=17, n_estimators=1000............
# [CV 3/5; 6/10] END criterion=gini, max_depth=17, n_estimators=1000;, score=0.907 total time=   2.8s
# [CV 4/5; 6/10] START criterion=gini, max_depth=17, n_estimators=1000............
# [CV 4/5; 6/10] END criterion=gini, max_depth=17, n_estimators=1000;, score=0.875 total time=   2.8s
# [CV 5/5; 6/10] START criterion=gini, max_depth=17, n_estimators=1000............
# [CV 5/5; 6/10] END criterion=gini, max_depth=17, n_estimators=1000;, score=0.863 total time=   2.9s
# [CV 1/5; 7/10] START criterion=entropy, max_depth=7, n_estimators=300...........
# [CV 1/5; 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.865 total time=   0.7s
# [CV 2/5; 7/10] START criterion=entropy, max_depth=7, n_estimators=300...........
# [CV 2/5; 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.875 total time=   0.7s
# [CV 3/5; 7/10] START criterion=entropy, max_depth=7, n_estimators=300...........
# [CV 3/5; 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.880 total time=   0.7s
# [CV 4/5; 7/10] START criterion=entropy, max_depth=7, n_estimators=300...........
# [CV 4/5; 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.863 total time=   0.6s
# [CV 5/5; 7/10] START criterion=entropy, max_depth=7, n_estimators=300...........
# [CV 5/5; 7/10] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.855 total time=   0.7s
# [CV 1/5; 8/10] START criterion=gini, max_depth=9, n_estimators=400..............
# [CV 1/5; 8/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.877 total time=   1.5s
# [CV 2/5; 8/10] START criterion=gini, max_depth=9, n_estimators=400..............
# [CV 2/5; 8/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.885 total time=   1.1s
# [CV 3/5; 8/10] START criterion=gini, max_depth=9, n_estimators=400..............
# [CV 3/5; 8/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.900 total time=   1.0s
# [CV 4/5; 8/10] START criterion=gini, max_depth=9, n_estimators=400..............
# [CV 4/5; 8/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.860 total time=   1.0s
# [CV 5/5; 8/10] START criterion=gini, max_depth=9, n_estimators=400..............
# [CV 5/5; 8/10] END criterion=gini, max_depth=9, n_estimators=400;, score=0.853 total time=   1.0s
# [CV 1/5; 9/10] START criterion=gini, max_depth=19, n_estimators=1100............
# [CV 1/5; 9/10] END criterion=gini, max_depth=19, n_estimators=1100;, score=0.892 total time=   3.2s
# [CV 2/5; 9/10] START criterion=gini, max_depth=19, n_estimators=1100............
# [CV 2/5; 9/10] END criterion=gini, max_depth=19, n_estimators=1100;, score=0.900 total time=   3.2s
# [CV 3/5; 9/10] START criterion=gini, max_depth=19, n_estimators=1100............
# [CV 3/5; 9/10] END criterion=gini, max_depth=19, n_estimators=1100;, score=0.902 total time=   3.3s
# [CV 4/5; 9/10] START criterion=gini, max_depth=19, n_estimators=1100............
# [CV 4/5; 9/10] END criterion=gini, max_depth=19, n_estimators=1100;, score=0.870 total time=   3.1s
# [CV 5/5; 9/10] START criterion=gini, max_depth=19, n_estimators=1100............
# [CV 5/5; 9/10] END criterion=gini, max_depth=19, n_estimators=1100;, score=0.870 total time=   3.4s
# [CV 1/5; 10/10] START criterion=entropy, max_depth=1, n_estimators=1200.........
# [CV 1/5; 10/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.557 total time=   1.9s
# [CV 2/5; 10/10] START criterion=entropy, max_depth=1, n_estimators=1200.........
# [CV 2/5; 10/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.542 total time=   1.9s
# [CV 3/5; 10/10] START criterion=entropy, max_depth=1, n_estimators=1200.........
# [CV 3/5; 10/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.562 total time=   2.0s
# [CV 4/5; 10/10] START criterion=entropy, max_depth=1, n_estimators=1200.........
# [CV 4/5; 10/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.578 total time=   1.9s
# [CV 5/5; 10/10] START criterion=entropy, max_depth=1, n_estimators=1200.........
# [CV 5/5; 10/10] END criterion=entropy, max_depth=1, n_estimators=1200;, score=0.550 total time=   2.3s
# Best Score: 0.8869999999999999
# Best Parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 19, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 1100, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ### Grid/Random Search With Pipeline

# %%
class MyRandomForestPipeline:
    def __init__(self, n_iter=10):
        self.scaler = preprocessing.StandardScaler()
        self.pca = decomposition.PCA()
        self.rf = ensemble.RandomForestClassifier(n_jobs= -1)
        self.classifier = pipeline.Pipeline([
            ('scaling', self.scaler),
            ('pca', self.pca),
            ('rf', self.rf)
        ])
        self.param_grid = {
            'pca__n_components': np.arange(5, 10),
            'rf__n_estimators': np.arange(100, 1500, 100),
            'rf__max_depth': np.arange(1, 20),
            'rf__criterion': ['gini', 'entropy']
        }
        self.model = None
        self.n_iter = n_iter

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=-1, cv=5):
        self.model = RandomizedSearchCV(
            estimator=self.classifier,
            param_distributions=self.param_grid,
            scoring=scoring,
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv,
            n_iter=self.n_iter
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage

my_pipeline = MyRandomForestPipeline(n_iter=10)
my_pipeline.fit(X, y)
my_pipeline.print_best_results()
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Score: 0.40700000000000003
# Best Parameters: {'memory': None, 'steps': [('scaling', StandardScaler()), ('pca', PCA(n_components=8)), ('rf', RandomForestClassifier(max_depth=12, n_estimators=1400, n_jobs=-1))], 'verbose': False, 'scaling': StandardScaler(), 'pca': PCA(n_components=8), 'rf': RandomForestClassifier(max_depth=12, n_estimators=1400, n_jobs=-1), 'scaling__copy': True, 'scaling__with_mean': True, 'scaling__with_std': True, 'pca__copy': True, 'pca__iterated_power': 'auto', 'pca__n_components': 8, 'pca__n_oversamples': 10, 'pca__power_iteration_normalizer': 'auto', 'pca__random_state': None, 'pca__svd_solver': 'auto', 'pca__tol': 0.0, 'pca__whiten': False, 'rf__bootstrap': True, 'rf__ccp_alpha': 0.0, 'rf__class_weight': None, 'rf__criterion': 'gini', 'rf__max_depth': 12, 'rf__max_features': 'sqrt', 'rf__max_leaf_nodes': None, 'rf__max_samples': None, 'rf__min_impurity_decrease': 0.0, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__min_weight_fraction_leaf': 0.0, 'rf__n_estimators': 1400, 'rf__n_jobs': -1, 'rf__oob_score': False, 'rf__random_state': None, 'rf__verbose': 0, 'rf__warm_start': False}

# %% [markdown]
# ### Bayesian Optimization with Gaussian Process

# %%
"""""
from functools import partial
from sklearn import metrics, ensemble, model_selection
from sklearn import metrics, ensemble, model_selection
import numpy as np
from functools import partial
"""""

"""""
cant import skopt for this functions 
def optimize(params, param_names, x, y):
    params = dict(zip(param_names, params))
    model = ensemble.RandomForestClassifier(**params)
    kf = model_selection.StratifiedKFold(n_splits= 5)
    accuracies = []
    for idx in kf.split( X= x, y=y):
        train_idx, test_idx = idx[0], idx[1]
        xtrain =x[train_idx]
        ytrain = y[train_idx]
        
        xtest = x[test_idx]
        ytest = y[test_idx]
        
        model.fit(xtrain, ytrain)
        preds = model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest, preds)
        accuracies.append(fold_acc)
        
    return -1.0 * np.mean(accuracies)


param_space = [
    space.Integer(3,15, name='max_depth'),
    space.Integer(100, 600, name='n_estimators'),
    space.Categorical(['gini', 'entropy'], name='criterion'),
    space.Real(0.01, 1, prior='uniform' ,name='max_features')
]
params_names = ['max_depth', 'n_estimators', 'criterion', 'max_features']

optimization_function = partial(
    optimize,
    param_names= param_names,
    x= X,
    y = y
)

result = gp_minimize(
    optimization_function,
    dimensions = param_space,
    n_calls= 15,
    n_random_starts=10,
    verbose=10,
)

print(
    dict(
        param_names,
        results.x
    )
)







same function without the use of skopt






def optimize(params, param_names, x, y):
    model_params = {
        param_names[i]: params[i] for i in range(len(param_names))
    }
    model = ensemble.RandomForestClassifier(**model_params)
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x, y=y):
        train_idx, test_idx = idx[0], idx[1]
        xtrain, ytrain = x[train_idx], y[train_idx]
        xtest, ytest = x[test_idx], y[test_idx]
        model.fit(xtrain, ytrain)
        preds = model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest, preds)
        accuracies.append(fold_acc)
    return -1.0 * np.mean(accuracies)

def grid_search(param_space, param_names, x, y, n_points=10):
    best_params = None
    best_score = float('-inf')

    for _ in range(n_points):
        params = [np.random.uniform(low, high) if isinstance(low, float) else np.random.randint(low, high + 1) for low, high in param_space]
        score = optimize(params, param_names, x, y)

        if score > best_score:
            best_score = score
            best_params = params

    return best_params

param_space = [
    (3, 15),           # max_depth
    (100, 600),        # n_estimators
    (0.01, 1.0),        # max_features
    (0, 1)             # For categorical criterion; 0 corresponds to 'gini' and 1 to 'entropy'
]

param_names = ['max_depth', 'n_estimators', 'max_features', 'criterion']

best_params = grid_search(param_space, param_names, X, y, n_points=15)
print({param_names[i]: best_params[i] for i in range(len(param_names))})
"""
# Out:
# '""\ncant import skopt for this functions \ndef optimize(params, param_names, x, y):\n    params = dict(zip(param_names, params))\n    model = ensemble.RandomForestClassifier(**params)\n    kf = model_selection.StratifiedKFold(n_splits= 5)\n    accuracies = []\n    for idx in kf.split( X= x, y=y):\n        train_idx, test_idx = idx[0], idx[1]\n        xtrain =x[train_idx]\n        ytrain = y[train_idx]\n        \n        xtest = x[test_idx]\n        ytest = y[test_idx]\n        \n        model.fit(xtrain, ytrain)\n        preds = model.predict(xtest)\n        fold_acc = metrics.accuracy_score(ytest, preds)\n        accuracies.append(fold_acc)\n        \n    return -1.0 * np.mean(accuracies)\n\n\nparam_space = [\n    space.Integer(3,15, name=\'max_depth\'),\n    space.Integer(100, 600, name=\'n_estimators\'),\n    space.Categorical([\'gini\', \'entropy\'], name=\'criterion\'),\n    space.Real(0.01, 1, prior=\'uniform\' ,name=\'max_features\')\n]\nparams_names = [\'max_depth\', \'n_estimators\', \'criterion\', \'max_features\']\n\noptimization_function = partial(\n    optimize,\n    param_names= param_names,\n    x= X,\n    y = y\n)\n\nresult = gp_minimize(\n    optimization_function,\n    dimensions = param_space,\n    n_calls= 15,\n    n_random_starts=10,\n    verbose=10,\n)\n\nprint(\n    dict(\n        param_names,\n        results.x\n    )\n)\n\n\n\n\n\n\n\nsame function without the use of skopt\n\n\n\n\n\n\ndef optimize(params, param_names, x, y):\n    model_params = {\n        param_names[i]: params[i] for i in range(len(param_names))\n    }\n    model = ensemble.RandomForestClassifier(**model_params)\n    kf = model_selection.StratifiedKFold(n_splits=5)\n    accuracies = []\n    for idx in kf.split(X=x, y=y):\n        train_idx, test_idx = idx[0], idx[1]\n        xtrain, ytrain = x[train_idx], y[train_idx]\n        xtest, ytest = x[test_idx], y[test_idx]\n        model.fit(xtrain, ytrain)\n        preds = model.predict(xtest)\n        fold_acc = metrics.accuracy_score(ytest, preds)\n        accuracies.append(fold_acc)\n    return -1.0 * np.mean(accuracies)\n\ndef grid_search(param_space, param_names, x, y, n_points=10):\n    best_params = None\n    best_score = float(\'-inf\')\n\n    for _ in range(n_points):\n        params = [np.random.uniform(low, high) if isinstance(low, float) else np.random.randint(low, high + 1) for low, high in param_space]\n        score = optimize(params, param_names, x, y)\n\n        if score > best_score:\n            best_score = score\n            best_params = params\n\n    return best_params\n\nparam_space = [\n    (3, 15),           # max_depth\n    (100, 600),        # n_estimators\n    (0.01, 1.0),        # max_features\n    (0, 1)             # For categorical criterion; 0 corresponds to \'gini\' and 1 to \'entropy\'\n]\n\nparam_names = [\'max_depth\', \'n_estimators\', \'max_features\', \'criterion\']\n\nbest_params = grid_search(param_space, param_names, X, y, n_points=15)\nprint({param_names[i]: best_params[i] for i in range(len(param_names))})\n'

# %% [markdown]
# ## Optuna

# %%
import optuna 
from functools import partial

# %%
# Typo on inserting the wrong XXXXXX


"""""
import optuna
from sklearn import metrics, ensemble, model_selection
from functools import partial

def optimize(trial, x, y):
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    n_estimators = trial.suggest_int('n_estimators', 100, 1500)
    max_depth = trial.suggest_int('max_depth', 3, 15)
    max_features = trial.suggest_uniform('max_features', 0.01, 1.0)

    model = ensemble.RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        criterion=criterion
    )
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x, y=y):  ###X=X is the correct version, change all x to X
        train_idx, test_idx = idx[0], idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]

        xtest = x[test_idx]
        ytest = y[test_idx]

        model.fit(xtrain, ytrain)
        preds = model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest, preds)
        accuracies.append(fold_acc)

    return -1.0 * np.mean(accuracies)

optimization_function = partial(optimize, x=X, y=y)

class OptunaRandomForestSearch:
    def __init__(self, n_jobs=-1):
        self.n_jobs = n_jobs
        self.best_params = None

    def optimize(self, n_trials=50):
        study = optuna.create_study(direction='minimize')
        study.optimize(optimization_function, n_trials=n_trials)

        self.best_params = study.best_params

    def print_best_results(self):
        print("Best Parameters:", self.best_params)

# Usage
# Assuming X, y, and OptunaRandomForestSearch are defined
optuna_random_forest_search = OptunaRandomForestSearch(n_jobs=-1)
optuna_random_forest_search.optimize(n_trials=50)
optuna_random_forest_search.print_best_results()
"""""
# Out:
# [I 2024-01-22 19:51:23,123] A new study created in memory with name: no-name-d97a290b-59d5-45eb-a249-defec51161c5
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:52:13,468] Trial 0 finished with value: -0.8875 and parameters: {'criterion': 'gini', 'n_estimators': 1364, 'max_depth': 7, 'max_features': 0.4103747794299047}. Best is trial 0 with value: -0.8875.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:52:33,771] Trial 1 finished with value: -0.7765000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 1297, 'max_depth': 9, 'max_features': 0.025532469337571882}. Best is trial 0 with value: -0.8875.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:53:18,939] Trial 2 finished with value: -0.7675 and parameters: {'criterion': 'gini', 'n_estimators': 1411, 'max_depth': 3, 'max_features': 0.957543904918412}. Best is trial 0 with value: -0.8875.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:53:40,912] Trial 3 finished with value: -0.7765000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 892, 'max_depth': 13, 'max_features': 0.08831380067800437}. Best is trial 0 with value: -0.8875.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:54:50,230] Trial 4 finished with value: -0.909 and parameters: {'criterion': 'entropy', 'n_estimators': 849, 'max_depth': 13, 'max_features': 0.8747648829544079}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:54:55,148] Trial 5 finished with value: -0.6445000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 497, 'max_depth': 4, 'max_features': 0.08847823275851398}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:55:10,237] Trial 6 finished with value: -0.8535 and parameters: {'criterion': 'entropy', 'n_estimators': 515, 'max_depth': 5, 'max_features': 0.36724972471856726}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:56:37,930] Trial 7 finished with value: -0.8789999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 1424, 'max_depth': 5, 'max_features': 0.9479344238698449}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:57:46,965] Trial 8 finished with value: -0.9075000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1064, 'max_depth': 15, 'max_features': 0.6132753222262302}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:57:48,435] Trial 9 finished with value: -0.7394999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 105, 'max_depth': 5, 'max_features': 0.14492654419634174}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:58:30,798] Trial 10 finished with value: -0.9015000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 626, 'max_depth': 12, 'max_features': 0.7471953912465614}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 19:59:38,535] Trial 11 finished with value: -0.9075 and parameters: {'criterion': 'entropy', 'n_estimators': 1003, 'max_depth': 15, 'max_features': 0.6724245308880497}. Best is trial 4 with value: -0.909.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:00:54,709] Trial 12 finished with value: -0.9095000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1071, 'max_depth': 15, 'max_features': 0.7048882417078632}. Best is trial 12 with value: -0.9095000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:02:21,019] Trial 13 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 1113, 'max_depth': 12, 'max_features': 0.8166958421992049}. Best is trial 12 with value: -0.9095000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:03:20,370] Trial 14 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 731, 'max_depth': 10, 'max_features': 0.8537151237488472}. Best is trial 12 with value: -0.9095000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:04:11,570] Trial 15 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 827, 'max_depth': 14, 'max_features': 0.5952352447136183}. Best is trial 12 with value: -0.9095000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:04:40,065] Trial 16 finished with value: -0.9045 and parameters: {'criterion': 'entropy', 'n_estimators': 313, 'max_depth': 10, 'max_features': 0.9941063092210181}. Best is trial 12 with value: -0.9095000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:06:11,640] Trial 17 finished with value: -0.9099999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 1230, 'max_depth': 13, 'max_features': 0.7604498728878826}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:07:32,785] Trial 18 finished with value: -0.9 and parameters: {'criterion': 'gini', 'n_estimators': 1208, 'max_depth': 11, 'max_features': 0.7278684828029087}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:08:44,387] Trial 19 finished with value: -0.9035 and parameters: {'criterion': 'entropy', 'n_estimators': 1214, 'max_depth': 14, 'max_features': 0.5462013682516603}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:10:32,487] Trial 20 finished with value: -0.9055000000000002 and parameters: {'criterion': 'entropy', 'n_estimators': 1490, 'max_depth': 8, 'max_features': 0.7551798399010898}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:11:48,698] Trial 21 finished with value: -0.9075000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 938, 'max_depth': 13, 'max_features': 0.863086654955813}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:13:06,561] Trial 22 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 1128, 'max_depth': 15, 'max_features': 0.6638904101269315}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:14:10,588] Trial 23 finished with value: -0.905 and parameters: {'criterion': 'entropy', 'n_estimators': 787, 'max_depth': 13, 'max_features': 0.8853480220665016}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:15:44,183] Trial 24 finished with value: -0.9085000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1255, 'max_depth': 12, 'max_features': 0.7970937642331136}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:17:09,576] Trial 25 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1006, 'max_depth': 14, 'max_features': 0.9081743424835055}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:17:55,557] Trial 26 finished with value: -0.9035 and parameters: {'criterion': 'gini', 'n_estimators': 646, 'max_depth': 11, 'max_features': 0.7831229194360508}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:18:58,877] Trial 27 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 890, 'max_depth': 14, 'max_features': 0.7002227028485837}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:20:31,960] Trial 28 finished with value: -0.9075000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1145, 'max_depth': 11, 'max_features': 0.8655122155624332}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:21:35,058] Trial 29 finished with value: -0.892 and parameters: {'criterion': 'gini', 'n_estimators': 1325, 'max_depth': 8, 'max_features': 0.5105699020592227}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:23:04,269] Trial 30 finished with value: -0.9045 and parameters: {'criterion': 'entropy', 'n_estimators': 1009, 'max_depth': 13, 'max_features': 0.9942025768143714}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:24:40,332] Trial 31 finished with value: -0.9079999999999998 and parameters: {'criterion': 'entropy', 'n_estimators': 1232, 'max_depth': 12, 'max_features': 0.8046116569725222}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:26:15,561] Trial 32 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 1281, 'max_depth': 15, 'max_features': 0.7986673570811386}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:28:14,731] Trial 33 finished with value: -0.9065 and parameters: {'criterion': 'entropy', 'n_estimators': 1401, 'max_depth': 12, 'max_features': 0.9188985061673315}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:29:39,658] Trial 34 finished with value: -0.9035 and parameters: {'criterion': 'gini', 'n_estimators': 1277, 'max_depth': 10, 'max_features': 0.7174693080525344}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:31:10,603] Trial 35 finished with value: -0.9095000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1167, 'max_depth': 14, 'max_features': 0.8327395230336657}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:32:28,026] Trial 36 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 911, 'max_depth': 14, 'max_features': 0.9261487548506171}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:33:52,052] Trial 37 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1076, 'max_depth': 13, 'max_features': 0.834744995651801}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:35:05,492] Trial 38 finished with value: -0.9025000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 1170, 'max_depth': 15, 'max_features': 0.6334544512162774}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:36:44,388] Trial 39 finished with value: -0.9085000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1380, 'max_depth': 14, 'max_features': 0.7478645032245743}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:37:53,060] Trial 40 finished with value: -0.899 and parameters: {'criterion': 'entropy', 'n_estimators': 818, 'max_depth': 7, 'max_features': 0.9570411613468648}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:39:44,828] Trial 41 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1493, 'max_depth': 13, 'max_features': 0.7755503946928539}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:41:07,757] Trial 42 finished with value: -0.905 and parameters: {'criterion': 'entropy', 'n_estimators': 1061, 'max_depth': 12, 'max_features': 0.8300782238804297}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:42:38,831] Trial 43 finished with value: -0.909 and parameters: {'criterion': 'entropy', 'n_estimators': 1332, 'max_depth': 15, 'max_features': 0.6964169740562844}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:44:13,127] Trial 44 finished with value: -0.9095000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1321, 'max_depth': 15, 'max_features': 0.7002424046785993}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:45:18,864] Trial 45 finished with value: -0.9075 and parameters: {'criterion': 'entropy', 'n_estimators': 962, 'max_depth': 15, 'max_features': 0.6527088730714519}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:46:31,853] Trial 46 finished with value: -0.9085000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1172, 'max_depth': 14, 'max_features': 0.5990245860917045}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:46:55,644] Trial 47 finished with value: -0.7675 and parameters: {'criterion': 'entropy', 'n_estimators': 664, 'max_depth': 3, 'max_features': 0.8800918205177004}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:47:31,805] Trial 48 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 506, 'max_depth': 13, 'max_features': 0.7426306822051617}. Best is trial 17 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\2006694676.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 20:49:10,386] Trial 49 finished with value: -0.9015000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 1441, 'max_depth': 15, 'max_features': 0.7044228338676178}. Best is trial 17 with value: -0.9099999999999999.
# Best Parameters: {'criterion': 'entropy', 'n_estimators': 1230, 'max_depth': 13, 'max_features': 0.7604498728878826}

# %%
import optuna
from sklearn import metrics, ensemble, model_selection
from functools import partial

def optimize(trial, X, y):  # Corrected X here
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    n_estimators = trial.suggest_int('n_estimators', 100, 1500)
    max_depth = trial.suggest_int('max_depth', 3, 15)
    max_features = trial.suggest_uniform('max_features', 0.01, 1.0)

    model = ensemble.RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        criterion=criterion
    )
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=X, y=y):  # Corrected X here
        train_idx, test_idx = idx[0], idx[1]
        xtrain = X[train_idx]  # Corrected X here
        ytrain = y[train_idx]

        xtest = X[test_idx]  # Corrected X here
        ytest = y[test_idx]

        model.fit(xtrain, ytrain)
        preds = model.predict(xtest)
        fold_acc = metrics.accuracy_score(ytest, preds)
        accuracies.append(fold_acc)

    return -1.0 * np.mean(accuracies)

optimization_function = partial(optimize, X=X, y=y)

class OptunaRandomForestSearch:
    def __init__(self, n_jobs=-1):
        self.n_jobs = n_jobs
        self.best_params = None

    def optimize(self, n_trials=50):
        study = optuna.create_study(direction='minimize')
        study.optimize(optimization_function, n_trials=n_trials)

        self.best_params = study.best_params

    def print_best_results(self):
        print("Best Parameters:", self.best_params)

# Usage
# Assuming X, y, and OptunaRandomForestSearch are defined
optuna_random_forest_search = OptunaRandomForestSearch(n_jobs=-1)
optuna_random_forest_search.optimize(n_trials=50)
optuna_random_forest_search.print_best_results()
# Out:
# [I 2024-01-22 21:21:13,316] A new study created in memory with name: no-name-71ee025d-b5ba-4776-9537-b0ae80f3b138
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:21:39,070] Trial 0 finished with value: -0.9019999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 459, 'max_depth': 13, 'max_features': 0.5396741128923808}. Best is trial 0 with value: -0.9019999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:22:41,906] Trial 1 finished with value: -0.9029999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 1190, 'max_depth': 10, 'max_features': 0.4117219344873095}. Best is trial 1 with value: -0.9029999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:23:10,782] Trial 2 finished with value: -0.772 and parameters: {'criterion': 'entropy', 'n_estimators': 1280, 'max_depth': 12, 'max_features': 0.09489436141348773}. Best is trial 1 with value: -0.9029999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:23:26,452] Trial 3 finished with value: -0.8800000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 453, 'max_depth': 6, 'max_features': 0.4991812396029813}. Best is trial 1 with value: -0.9029999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:23:48,443] Trial 4 finished with value: -0.807 and parameters: {'criterion': 'entropy', 'n_estimators': 1410, 'max_depth': 3, 'max_features': 0.26658427167862936}. Best is trial 1 with value: -0.9029999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:24:28,389] Trial 5 finished with value: -0.8924999999999998 and parameters: {'criterion': 'entropy', 'n_estimators': 932, 'max_depth': 12, 'max_features': 0.28303315988513184}. Best is trial 1 with value: -0.9029999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:25:00,549] Trial 6 finished with value: -0.8285 and parameters: {'criterion': 'entropy', 'n_estimators': 1122, 'max_depth': 4, 'max_features': 0.4756710525824038}. Best is trial 1 with value: -0.9029999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:26:09,069] Trial 7 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 900, 'max_depth': 8, 'max_features': 0.8280959590548228}. Best is trial 7 with value: -0.9065000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:26:13,642] Trial 8 finished with value: -0.7935 and parameters: {'criterion': 'entropy', 'n_estimators': 191, 'max_depth': 3, 'max_features': 0.5177011594716455}. Best is trial 7 with value: -0.9065000000000001.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:28:05,224] Trial 9 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1208, 'max_depth': 10, 'max_features': 0.9526664039076502}. Best is trial 9 with value: -0.907.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:30:21,716] Trial 10 finished with value: -0.893 and parameters: {'criterion': 'gini', 'n_estimators': 1479, 'max_depth': 15, 'max_features': 0.9877529464706288}. Best is trial 9 with value: -0.907.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:31:42,175] Trial 11 finished with value: -0.905 and parameters: {'criterion': 'entropy', 'n_estimators': 857, 'max_depth': 8, 'max_features': 0.9623412728590502}. Best is trial 9 with value: -0.907.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:32:32,233] Trial 12 finished with value: -0.9059999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 627, 'max_depth': 8, 'max_features': 0.7983375985874189}. Best is trial 9 with value: -0.907.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:33:52,178] Trial 13 finished with value: -0.9075 and parameters: {'criterion': 'entropy', 'n_estimators': 979, 'max_depth': 10, 'max_features': 0.802479530767126}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:35:05,209] Trial 14 finished with value: -0.9025000000000001 and parameters: {'criterion': 'gini', 'n_estimators': 1060, 'max_depth': 10, 'max_features': 0.7198003940268111}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:35:52,918] Trial 15 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 689, 'max_depth': 10, 'max_features': 0.6800632686463298}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:37:08,105] Trial 16 finished with value: -0.8950000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1042, 'max_depth': 6, 'max_features': 0.8903752315305034}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:39:01,526] Trial 17 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 1279, 'max_depth': 14, 'max_features': 0.8783962865451451}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:41:06,297] Trial 18 finished with value: -0.8949999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 1344, 'max_depth': 11, 'max_features': 0.99155102354643}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:42:09,381] Trial 19 finished with value: -0.8939999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 991, 'max_depth': 6, 'max_features': 0.735889104509714}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:42:59,049] Trial 20 finished with value: -0.9045 and parameters: {'criterion': 'entropy', 'n_estimators': 742, 'max_depth': 9, 'max_features': 0.6377183656805536}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:44:06,432] Trial 21 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 827, 'max_depth': 8, 'max_features': 0.8319220594974567}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:45:39,387] Trial 22 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 1183, 'max_depth': 7, 'max_features': 0.8009164961625593}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:47:08,064] Trial 23 finished with value: -0.9065000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 918, 'max_depth': 11, 'max_features': 0.8967835373122681}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:47:53,139] Trial 24 finished with value: -0.9055000000000002 and parameters: {'criterion': 'entropy', 'n_estimators': 536, 'max_depth': 9, 'max_features': 0.7688085266067256}. Best is trial 13 with value: -0.9075.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:49:16,078] Trial 25 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 1105, 'max_depth': 11, 'max_features': 0.6296884408229985}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:50:34,506] Trial 26 finished with value: -0.9045 and parameters: {'criterion': 'gini', 'n_estimators': 1140, 'max_depth': 12, 'max_features': 0.6367760358719916}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:52:33,805] Trial 27 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 1285, 'max_depth': 11, 'max_features': 0.9034552859980783}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:53:57,501] Trial 28 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1057, 'max_depth': 14, 'max_features': 0.7004158371638922}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:54:21,492] Trial 29 finished with value: -0.9065 and parameters: {'criterion': 'gini', 'n_estimators': 360, 'max_depth': 13, 'max_features': 0.5968288260469914}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:55:29,496] Trial 30 finished with value: -0.9045 and parameters: {'criterion': 'entropy', 'n_estimators': 759, 'max_depth': 13, 'max_features': 0.7755259557065329}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:56:48,404] Trial 31 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1039, 'max_depth': 14, 'max_features': 0.6882000939809189}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:58:11,580] Trial 32 finished with value: -0.9055000000000002 and parameters: {'criterion': 'entropy', 'n_estimators': 1220, 'max_depth': 15, 'max_features': 0.5941420647560269}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 21:59:28,737] Trial 33 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 983, 'max_depth': 10, 'max_features': 0.7209518424216002}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:01:09,906] Trial 34 finished with value: -0.9065 and parameters: {'criterion': 'entropy', 'n_estimators': 1103, 'max_depth': 11, 'max_features': 0.9268481627944016}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:02:34,611] Trial 35 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 1222, 'max_depth': 13, 'max_features': 0.5765040432382327}. Best is trial 25 with value: -0.908.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:04:08,173] Trial 36 finished with value: -0.9099999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 1368, 'max_depth': 12, 'max_features': 0.5692850291373351}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:05:43,286] Trial 37 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 1387, 'max_depth': 13, 'max_features': 0.5506852585383695}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:06:59,876] Trial 38 finished with value: -0.9019999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 1411, 'max_depth': 13, 'max_features': 0.4309933018048896}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:08:37,927] Trial 39 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 1474, 'max_depth': 12, 'max_features': 0.5513886886719813}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:10:01,882] Trial 40 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1375, 'max_depth': 12, 'max_features': 0.4548179384813079}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:11:40,379] Trial 41 finished with value: -0.909 and parameters: {'criterion': 'entropy', 'n_estimators': 1495, 'max_depth': 12, 'max_features': 0.546918946732525}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:13:05,539] Trial 42 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1310, 'max_depth': 12, 'max_features': 0.5214346963343338}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:14:27,100] Trial 43 finished with value: -0.9014999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 1426, 'max_depth': 14, 'max_features': 0.3856197310320351}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:15:53,174] Trial 44 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1249, 'max_depth': 13, 'max_features': 0.5556437381440171}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:17:26,653] Trial 45 finished with value: -0.905 and parameters: {'criterion': 'entropy', 'n_estimators': 1484, 'max_depth': 13, 'max_features': 0.4762499079270265}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:19:01,165] Trial 46 finished with value: -0.9035 and parameters: {'criterion': 'entropy', 'n_estimators': 1372, 'max_depth': 11, 'max_features': 0.5724043250918037}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:20:15,705] Trial 47 finished with value: -0.9035 and parameters: {'criterion': 'entropy', 'n_estimators': 1173, 'max_depth': 15, 'max_features': 0.4887436217526796}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:21:45,816] Trial 48 finished with value: -0.907 and parameters: {'criterion': 'entropy', 'n_estimators': 1346, 'max_depth': 12, 'max_features': 0.5207438248573591}. Best is trial 36 with value: -0.9099999999999999.
# C:\Users\enaba\AppData\Local\Temp\ipykernel_10748\382104579.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   max_features = trial.suggest_uniform('max_features', 0.01, 1.0)
# [I 2024-01-22 22:23:26,419] Trial 49 finished with value: -0.901 and parameters: {'criterion': 'gini', 'n_estimators': 1441, 'max_depth': 14, 'max_features': 0.6117335105829924}. Best is trial 36 with value: -0.9099999999999999.
# Best Parameters: {'criterion': 'entropy', 'n_estimators': 1368, 'max_depth': 12, 'max_features': 0.5692850291373351}

# %% [markdown]
# #### Optimization History Plot

# %%
optuna.visualization.plot_optimization_history(study)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 optuna.visualization.plot_optimization_history(study)
#
# NameError: name 'study' is not defined

# %%
optuna.visualization.plot_parallel_coordinate(study)

# %%
1.Best Parameters: {'criterion': 'entropy', 'n_estimators': 1230, 'max_depth': 13, 'max_features': 0.7604498728878826}
2.Best Parameters: {'criterion': 'entropy', 'n_estimators': 1368, 'max_depth': 12, 'max_features': 0.5692850291373351}

# %%
optuna.visualization.plot_slice(study, params = ['criterion',
                                                 'entropy',
                                                 'n_estimators',
                                                 'max_depth',
                                                 'min_samples_split',
                                                 'max_features',
                                                 ])

# %%
optuna.visualization.plot_param_importances()

# %% [markdown]
# #### Assigning the Best Hyperparameters

# %%
best_criterion = best_params['criterion']##
best_criterion

# %%
best_entropy = best_params['entropy']
best_entropy

# %%
34
best_n_estimators = best_params['n_estimators']##
best_n_estimators

# %%
best_max_depth = best_params['max_depth']##
best_max_depth

# %%
best_min_samples_split = best_params['min_samples_split']
best_min_samples_split

# %%
best_max_features = best_params['max_features']
best_max_features

# %% [markdown]
# ## Ramdom Forest Model with The Best HyperParatmeters

# %%
class RandomForestGridSearch:
    def __init__(self, n_jobs=-1):  #-1 uses all the cpu to its max
        self.classifier = RandomForestClassifier(n_jobs=n_jobs)
        self.param_grid = {
            'n_estimators': best_n_estimators,
            'max_depth': best_max_depth,
            'criterion': best_criterion
        }
        self.model = None

    def fit(self, X, y, scoring='accuracy', verbose=10, n_jobs=1, cv=5):
        self.model = GridSearchCV(
            estimator=self.classifier,
            param_grid=self.param_grid,
            scoring=scoring, #all the classes have the same number of samples so we use accuracy
            verbose=verbose,
            n_jobs=n_jobs,
            cv=cv
        )
        self.model.fit(X, y)

    def print_best_results(self):
        print("Best Score:", self.model.best_score_)
        print("Best Parameters:", self.model.best_estimator_.get_params())

# Usage

random_forest_search = RandomForestGridSearch(n_jobs=-1)
random_forest_search.fit(X, y)
random_forest_search.print_best_results()
